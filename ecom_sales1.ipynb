# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammed1faisal/ecom_sales_python/blob/main/ecom_sales1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import io
from google.colab import files


data=files.upload()
# Out:
#      <input type="file" id="files-fccc48ef-7be5-43ab-9584-cf94538f20ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fccc48ef-7be5-43ab-9584-cf94538f20ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Ecommerce Purchases')

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# **NUMBER OF SALES IN THE SECOND HALF OF THE DAY**

# %%
len(df[df['AM or PM']=='PM'])
# Out:
# 5068

# %% [markdown]
# **FIND THE TOTAL NUMBER OF FRENCH SPEAKING CUSTOMERS.**

# %%
df.Language.unique()
# Out:
# array(['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it'], dtype=object)

# %%
df[df['Language']=='fr'].count()
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %%
len(df[df['Language']=='fr'])
# Out:
# 1097

# %%
df['Purchase Price'].max()
# Out:
# 99.99

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %% [markdown]
# **FIND THE NUMBER OF CUSTOMERS WHO ARE ENGINEERS**

# %%
df[df['Job'].str.contains('engineer',case=False)].count()
# Out:
# Address             984
# Lot                 984
# AM or PM            984
# Browser Info        984
# Company             984
# Credit Card         984
# CC Exp Date         984
# CC Security Code    984
# CC Provider         984
# Email               984
# Job                 984
# IP Address          984
# Language            984
# Purchase Price      984
# dtype: int64

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# **OBTAINING THE EMAIL ID OF THE CUSTOMER WHOSE IP ADDRESS IS 15.160.41.51**

# %%
df[df['IP Address']=='15.160.41.51']['Email']
# Out:
# 1    anthony41@reed.com
# Name: Email, dtype: object

# %% [markdown]
# **FIND THE NUMBER OF CUSTOMERS WHO HAVE MADE THE PAYMENT OF 50 DOLLORS AND ABOVE USING MASTERCARD**

# %%
len(df[(df['CC Provider']=='Mastercard') & (df['Purchase Price']>50)])
# Out:
# 405

# %% [markdown]
# **OBTAINING THE EMAIL OF THE CUSTOMER WHOSE CREDIT CARD NUMBER IS 011929061123406**

# %%
df[df['Credit Card']==6011929061123406]['Email']
# Out:
# 0    pdunlap@yahoo.com
# Name: Email, dtype: object

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# **FIND AT WHICH PART OF THE DAY DOES MORE SALES HAPPEN.(AM OR PM)**

# %%
df['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %% [markdown]
# **FIND THE NUMBER OF CUSTOMERS WHOSE CREDIT CARD EXPIRES IN 2020**

# %%
def funt():
  count=0
  for date in df['CC Exp Date']:
     if date.split('/')[1]=='20':
         count=count+1
  print(count)

# %%
funt()
# Out:
# 988

# %%
list=[]
for email in df['Email']:
  list.append(email.split('@')[1])

# %%
df['new col']=list

# %%
df.head(1)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
#
#                                         Browser Info          Company  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  Martinez-Herman
#
#         Credit Card CC Exp Date  CC Security Code   CC Provider  \
# 0  6011929061123406       02/20               900  JCB 16 digit
#
#                Email                                     Job       IP Address  \
# 0  pdunlap@yahoo.com  Scientist, product/process development  149.146.147.205
#
#   Language  Purchase Price    new col
# 0       el           98.14  yahoo.com

# %%
df['new col'].value_counts().head(4)
# Out:
# hotmail.com    1638
# yahoo.com      1616
# gmail.com      1605
# smith.com        42
# Name: new col, dtype: int64

# %%
df.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# Succesfully analysed the given data set
